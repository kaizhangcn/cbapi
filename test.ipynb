# %%
import cbapi

# %%
RAPIDAPI_KEY = "0352d64021msh703feee1708caeap1771c1jsnc30a4333d75a"

# %%
cb = cbapi.CrunchbaseAPI(RAPIDAPI_KEY)

# %%
cb.trigger_api_organization(updated_since = 1577890000, organization_types = 'school', max_threads = 4)
# Out:
# Retrieving page 1/9
# Retrieving page 4/9
# Retrieving page 6/9
# Retrieving page 2/9
# Retrieving page 5/9
# Retrieving page 7/9
# Retrieving page 1/9
# Retrieving page 3/9
# Retrieving page 8/9
#                                              permalink  \
# 0                                         add-to-event
# 1                                   sec-source-academy
# 2                                         careertips4u
# 3       swiss-institute-for-management-and-hospitality
# 4               pryazovskyi-state-technical-university
# ..                                                 ...
# 895        ucla-school-of-theater--film-and-television
# 896            david-geffen-school-of-medicine-at-ucla
# 897                                        ucla-cresst
# 898                        pritzker-school-of-medicine
# 899  monterrey-institute-of-technology-and-higher-e...
#
#                                               api_path  \
# ...

# %%
cb.trigger_api_people(updated_since = 1577890000, types = 'investor', max_threads = 4)
# Out:
# Retrieving page 1/155
# Retrieving page 38/155
# Retrieving page 76/155
# Retrieving page 114/155
# Retrieving page 77/155
# Retrieving page 1/155
# Retrieving page 39/155
# Retrieving page 115/155
# Retrieving page 78/155
# Retrieving page 2/155
# Retrieving page 40/155
# Retrieving page 116/155
# Retrieving page 79/155
# Retrieving page 3/155
# Retrieving page 41/155
# Retrieving page 117/155
# Retrieving page 80/155
# Retrieving page 4/155
# Retrieving page 42/155
# Retrieving page 118/155Retrieving page 81/155
#
# Retrieving page 5/155
# Retrieving page 119/155
# Retrieving page 82/155
# Retrieving page 43/155
# Retrieving page 6/155
# Retrieving page 120/155
# Retrieving page 44/155Retrieving page 7/155
#
# Retrieving page 83/155
# Retrieving page 121/155
# Retrieving page 8/155
# Retrieving page 45/155
# Retrieving page 84/155
# Retrieving page 122/155
# Retrieving page 9/155
# Retrieving page 46/155
# Retrieving page 85/155
# Retrieving page 123/155
# Retrieving page 10/155
# ...
